# %%
import pandas as pd 

df_edu = pd.read_csv("../dataset_archive/df_rate_merge_edu_whoexclude.csv")
df_edu
# Out:
#               trackers      2012      2013      2014      2015      2016  \
# 0     google-analytics  0.485063  0.517886  0.531293  0.547983  0.554492
# 1               google  0.126064  0.139138  0.147761  0.159388  0.171460
# 2           googleapis  0.116384  0.152601  0.181752  0.206342  0.219583
# 3             facebook  0.064701  0.070487  0.073936  0.080334  0.081725
# 4              addthis  0.035549  0.037997  0.039277  0.040278  0.038720
# ..                 ...       ...       ...       ...       ...       ...
# 194  ssl-images-amazon       NaN       NaN       NaN       NaN       NaN
# 195      valuecommerce       NaN       NaN       NaN       NaN       NaN
# 196             plista       NaN       NaN       NaN       NaN       NaN
# 197                 a8       NaN       NaN       NaN       NaN       NaN
# 198             demdex       NaN       NaN       NaN       NaN       NaN
#
#          2017      2018      2019      2020      2021
# ...

# %%
df_control = pd.read_csv("../dataset_archive/df_rate_merge_base_whoexclude.csv")
df_control
# Out:
#               trackers      2012      2013      2014      2015      2016  \
# 0     google-analytics  0.457135  0.477441  0.482503  0.492796  0.490236
# 1               google  0.125508  0.136745  0.140751  0.145647  0.143866
# 2           googleapis  0.114437  0.141530  0.160612  0.173074  0.178470
# 3             facebook  0.107371  0.112045  0.112545  0.109207  0.100695
# 4    googlesyndication  0.065090  0.061307  0.057024  0.054854  0.055299
# ..                 ...       ...       ...       ...       ...       ...
# 207           netscape       NaN  0.000056       NaN       NaN       NaN
# 208               2mdn       NaN       NaN  0.000056  0.000056  0.000056
# 209           exoclick       NaN       NaN       NaN  0.000056       NaN
# 210             imageg       NaN       NaN       NaN       NaN       NaN
# 211     browser-update       NaN       NaN       NaN       NaN       NaN
#
#          2017      2018      2019      2020      2021
# ...

# %%
set_edu = set(df_edu['trackers'].to_list())
set_nonedu = set(df_control['trackers'].to_list())
print(len(set(df_edu['trackers'].to_list())))
print(len(set(df_control['trackers'].to_list())))
# Out:
# 199
# 212

# %%
print(len(set_edu.union(set_nonedu)))
