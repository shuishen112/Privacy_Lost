# %% [markdown]
# # The notebook is to analyse the one_url_for_each_year

# %%
import pandas as pd 

df = pd.read_csv("../one_url_for_each_year.csv")
df.head()
# Out:
#    year                  url_host_name url_host_registered_domain  \
# 0  2016                    www.psoe.es                    psoe.es
# 1  2019                   www.bjiff.be                   bjiff.be
# 2  2015                   www.ddbst.de                   ddbst.de
# 3  2017  www.frankfurter-stiftungen.de  frankfurter-stiftungen.de
# 4  2019                    www.pd2h.nl                    pd2h.nl
#
#                                        warc_filename  \
# 0  crawl-data/CC-MAIN-2016-07/segments/1454701159...
# 1  crawl-data/CC-MAIN-2019-04/segments/1547584203...
# 2  crawl-data/CC-MAIN-2015-06/segments/1422122030...
# 3  crawl-data/CC-MAIN-2017-09/segments/1487501171...
# 4  crawl-data/CC-MAIN-2019-04/segments/1547583743...
#
#                                                  url  warc_record_offset  \
# 0                                http://www.psoe.es/           619604478
# 1                               http://www.bjiff.be/           260194590
# ...

# %%
len(df)
# Out:
# 3735773

# %%
df.groupby("url_host_name").count().describe()
# Out:
#                 year  url_host_registered_domain  warc_filename  \
# count  669485.000000               669485.000000  669485.000000
# mean        5.580070                    5.580070       5.580070
# std         2.717694                    2.717694       2.717694
# min         1.000000                    1.000000       1.000000
# 25%         3.000000                    3.000000       3.000000
# 50%         6.000000                    6.000000       6.000000
# 75%         7.000000                    7.000000       7.000000
# max        10.000000                   10.000000      10.000000
#
#                  url  warc_record_offset  warc_record_length        ranking
# count  669485.000000       669485.000000       669485.000000  669485.000000
# mean        5.580070            5.580070            5.580070       5.580070
# std         2.717694            2.717694            2.717694       2.717694
# min         1.000000            1.000000            1.000000       1.000000
# ...

# %%
# collect the dataset for there urls
